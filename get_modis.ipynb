# %%
import requests

# url = f"https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD09GA/{year}/{doy}.json"
url = "https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD09GA/2022/297.json"
print(url)
try:
    r = requests.get(url)
    print(r.status_code)
    if r.status_code == 200:
        print(r.status_code)
        arr1 = r.json()
        arr = arr1["content"]
        # print(arr)

        
        
        for a in arr:
            # print(a)
            name = a["name"].split(".")
            # print(name[2])
            if name[2] == 'h27v07':
                print(f'get HDF name: {a["name"]}')
                # getData(doy, a["name"], dd, year)
                # recordDoy(doy, dd, year)
    else:
        print("Not Found")
except requests.exceptions.HTTPError as err:
    raise SystemExit(err)
# Out:
# https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/61/MOD09GA/2022/296.json
# 200
# 200
# h01v07
# h02v06
# h03v05
# h04v05
# h06v03
# h07v03
# h08v03
# h09v02
# h09v03
# h10v02
# h10v03
# h11v01
# h11v02
# h12v01
# h12v02
# h13v01
# h13v02
# h14v00
# h14v01
# h15v00
# h15v01
# h15v17
# h16v17
# h17v16
# h17v17
# h18v16
# h18v17
# h19v15
# h19v16
# h19v17
# h20v00
# h20v01
# h20v16
# h20v17
# h21v00
# h21v01
# h21v15
# h21v16
# h21v17
# h22v01
# h22v15
# h22v16
# h23v01
# h23v02
# h23v15
# h23v16
# h24v01
# h24v02
# h24v15
# h25v02
# h26v02
# h26v03
# h27v03
# h27v14
# h28v03
# h28v04
# h28v12
# h28v13
# h28v14
# h29v03
# h29v12
# h29v13
# h30v04
# h30v05
# h30v11
# h30v12
# h30v13
# h31v04
# h31v06
# h31v11
# h31v12
# h31v13
# h32v07
# h32v10
# h32v11
# h32v12
# h33v07
# h33v08
# h33v09
# h33v10
# h33v11
# h34v07
# h34v08
# h34v09
# h34v10
# h35v08
# h35v09
# h35v10
